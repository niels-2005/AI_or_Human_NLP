# %%
import pandas as pd
from pipeline import pipe

# %%
# read csv
df = pd.read_csv("prep_AI_Human.csv")
df.head()
# Out:
#                                                 text  target
# 0  most people have experienced the feeling of ho...     1.0
# 1  everyone should have an opinion on what they t...     0.0
# 2  many people believe that it is necessary to us...     0.0
# 3  dear senator i am writing to express my strong...     1.0
# 4  in the would we live in today cams ame used by...     0.0

# %%
# enjoy the pipeline
pipe(df=df)
# Out:
# Creating Train, Test split...
#
#
# Done! check for balance ...
# Looks unbalanced! Balancing Train Set...
# Balanced!
#
#
# Fitting Pipeline...
#
#
# predicting...
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97     45274
#          1.0       0.96      0.93      0.95     27424
#
#     accuracy                           0.96     72698
#    macro avg       0.96      0.95      0.96     72698
# weighted avg       0.96      0.96      0.96     72698
